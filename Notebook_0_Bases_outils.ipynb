# %% [markdown]
# # Notebook 0 : Bases d'utilisation des outils

# %% [markdown]
# ## Étape 1 : Préparer l'environnement avec uv1. Installer **uv** (si ce n'est pas déjà fait).2. Créer un nouvel environnement : `uv venv .venv`.3. Activer l'environnement : `source .venv/bin/activate`.

# %% [markdown]
# ## Étape 2 : Cloner le dépôt avec GitHub Desktop et Gitea1. Depuis GitHub Desktop, ouvrez l'URL du dépôt Gitea.2. Clonez le dépôt sur votre machine.3. Utilisez GitHub Desktop pour créer vos commits et synchroniser vos modifications.

# %% [markdown]
# ## Étape 3 : Lancer Jupyter Notebook1. Installez Jupyter dans l'environnement : `pip install jupyter`.2. Lancez le serveur : `jupyter notebook`.

# %% [markdown]
# ## Étape 4 : Découverte de pandas1. Créez un nouveau notebook.2. Importez la bibliothèque : `import pandas as pd`.3. Chargez un petit fichier CSV et affichez les premières lignes :```pythondf = pd.read_csv('votre_fichier.csv')df.head()```
