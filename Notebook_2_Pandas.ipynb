# %% [markdown]
# # Notebook 2 : Découvrir Pandas

# %% [markdown]
# ## Importer différents types de fichiersPandas peut lire des CSV, des fichiers Excel ou encore du JSON.

# %%
import pandas as pd

# CSV
df_csv = pd.read_csv('data.csv')
# Excel
df_xls = pd.read_excel('data.xlsx')

# %% [markdown]
# ## Series et DataFrames

# %%
serie = pd.Series([1, 2, 3])
frame = pd.DataFrame({'col1': [1,2], 'col2': [3,4]})
frame

# %% [markdown]
# ## Exporter des données

# %%
frame.to_csv('export.csv', index=False)
