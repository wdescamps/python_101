# %% [markdown]
# # Notebook 1 : Python 101

# %% [markdown]
# ## Notebooks vs fichiers Python
# - Les *notebooks* permettent d'exécuter du code par cellules et d'ajouter des explications en Markdown.
# - Les *fichiers Python* (`.py`) sont des scripts exécutables d'un bloc.

# %% [markdown]
# ## Variables

# %%
x = 10
print(x)

# %% [markdown]
# ## Listes et dictionnaires

# %%
ma_liste = [1, 2, 3]
mon_dict = {'a': 1, 'b': 2}
print(ma_liste)
print(mon_dict)

# %% [markdown]
# ## Boucles

# %%
for element in ma_liste:
    print(element)

# %% [markdown]
# ## Fonctions

# %%
def carre(n):
    return n * n

carre(4)

# %% [markdown]
# ## Librairies Python : petit aperçu

# %%
import math
math.sqrt(16)
