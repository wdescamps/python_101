# %% [markdown]
# # Notebook 3 : Visualisation avec Plotly

# %% [markdown]
# Dans ce notebook, nous allons créer quelques graphiques simples en utilisant Plotly.

# %% [markdown]
# ## Installation et import

# %%
import plotly.express as px

# %% [markdown]
# ## Exemple de graphique

# %%
df = px.data.iris()
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species')
fig.show()
